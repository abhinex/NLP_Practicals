# %% [markdown]
# #### Stemming: stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or the to the roots of words known as lemma. Stemming is Important in NLP. main usage help to reduce the tokens that helps in convert to the Meaninfull vector

# %%
## Porter Stemming
